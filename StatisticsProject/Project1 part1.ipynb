# %% [markdown]
# # Project Part 1
#
# <b>Question 1:</b>
# ![img1.PNG](attachment:img1.PNG)
# 1. Refer to the above table and find the joint probability of the people who planned to purchase and actually placed an order.
# 2. Refer to the above table and find the joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase

# %%
#Answer 1

#part 1:
p1 = 400/2000
print("joint probability of people who planned to purchase and actually placed an order: ",p1)

#part 2:
p2 = 400/500
print("Joint probability of people who planned to purchase and actually placed an order,\ngiven that people planned to purchase: ",p2)
# Out:
# joint probability of people who planned to purchase and actually placed an order:  0.2
# Joint probability of people who planned to purchase and actually placed an order,
# given that people planned to purchase:  0.8

# %% [markdown]
# <b>Question 2</b>
#
# An electrical manufacturing company conducts quality checks at specified periods on the
# products it manufactures. Historically, the failure rate for the manufactured item is 5%. Suppose a random
# sample of 10 manufactured items is selected. Answer the following questions.
#
# A. Probability that none of the items are defective?
#
# B. Probability that exactly one of the items is defective?
#
# C. Probability that two or fewer of the items are defective?
#
# D. Probability that three or more of the items are defective ?

# %%
#Answer 2:

import numpy as np
import scipy.stats as stats
p3 = 0.05
k = np.arange(0,11)

#part 1:

binomial1 = stats.binom.pmf(k,10,0.05)
print('Probability that none of the items are defective %.3f'%binomial1[0])

#part 2:

print(' Probability that exactly one of the items is defective %.3f'%binomial1[1])

#part 3:

binomial2 = stats.binom.cdf(k,10,0.05)
print('Probability that two or fewer of the items are defective %.3f'%binomial2[2])

#part 4:

print('Probability that three or more of the items are defective %.3f'%(binomial2[10] - binomial2[2]))
# Out:
# Probability that none of the items are defective 0.599
#  Probability that exactly one of the items is defective 0.315
# Probability that two or fewer of the items are defective 0.988
# Probability that three or more of the items are defective 0.012

# %% [markdown]
# <b>Question 3:</b>
#
# A car salesman sells on an average 3 cars per week.
#
# A. Probability that in a given week he will sell some cars.
#
# B. Probability that in a given week he will sell 2 or more but less than 5 cars.
#
# C. Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold per week

# %%
import matplotlib.pyplot as plt

rate = 3
list1 = np.arange(0,20)
poisson = stats.poisson.pmf(list1,rate)

# part A
print('Probability that in a given week he will sell some cars',1-poisson[0])

#part 2
print('Probability that in a given week he will sell 2 or more but less than 5 cars',poisson[2]+poisson[3]+poisson[4])

poisson2 = stats.poisson.cdf(list1,rate)

plt.plot(list1,poisson2,'o-')
plt.title('Poisson: $\lambda$ = %i ' % rate)
plt.xlabel('Number of cars sold per week')
plt.ylabel('Cumulative probability of cars sold per week')
plt.show()
# Out:
# Probability that in a given week he will sell some cars 0.950212931632136
# Probability that in a given week he will sell 2 or more but less than 5 cars 0.6161149710523164

# %% [markdown]
# **Question 4:**
#
#  Accuracy in understanding orders for a speech based bot at a restaurant is important for the
# Company X which has designed, marketed and launched the product for a contactless delivery due to the
# COVID-19 pandemic. Recognition accuracy that measures the percentage of orders that are taken correctly is
# 86.8%. Suppose that you place order with the bot and two friends of yours independently place orders with
# the same bot. Answer the following questions.
#
# A. What is the probability that all three orders will be recognised correctly?
#
# B. What is the probability that none of the three orders will be recognised correctly?
#
# C. What is the probability that at least two of the three orders will be recognised correctly?

# %%
meanprob = 0.868
friends = 3
list2 = np.arange(0,4)

binomans = stats.binom.pmf(list2,friends,meanprob)
binomans

#part a

print('1. All the three orders are recognized correctly? is %1.4f' %binomans[3])

# part b

print('2. None of the three orders are recognized correctly? is %1.4f' %binomans[0])

#part c

print('At least two of the three orders will be recognised correctly is ',round((binomans[3]+binomans[2]),4))
# Out:
# 1. All the three orders are recognized correctly? is 0.6540
# 2. None of the three orders are recognized correctly? is 0.0023
# At least two of the three orders will be recognised correctly is  0.9523

# %% [markdown]
# **Question 5:**
#
# A group of 300 professionals sat for a competitive exam. The results show the information of
# marks obtained by them have a mean of 60 and a standard deviation of 12. The pattern of marks follows a
# normal distribution. Answer the following questions.
#
# A. What is the percentage of students who score more than 80.
#
# B. What is the percentage of students who score less than 50.
#
# C. What should be the distinction mark if the highest 10% of students are to be awarded distinction

# %%
mean = 60
sd = 12
z1 = (80 - 60)/sd

# part A
print("Percentage of students who score more than 80 is ",round((1-stats.norm.cdf(z1))*100,3))


# part 2 

z2 = (50 - 60)/sd
print("Percentage of students who score  less than 50 is ",round((stats.norm.cdf(z2))*100,3))

#part 3

mark = (sd*(stats.norm.ppf(0.9))) + 60
print('distinction mark if the highest 10% of students are to be awarded distinction',round(mark,3))
# Out:
# Percentage of students who score more than 80 is  4.779
# Percentage of students who score  less than 50 is  20.233
# distinction mark if the highest 10% of students are to be awarded distinction 75.379

# %% [markdown]
# **Question 6**
#
# Explain 1 real life industry scenario where you can use the
# concepts learnt in this module of Applied statistics to get a data driven business solution.

# %% [markdown]
# **Answer**
#
# - I have been trding from a long time and at times it gets really cumbersome to look at varoius charts to inherit the hiding info.
#
# - A software canbe developed that captures moving averages of diiferent company charts in different periods (20 days to 5 days)
#
# - Whenever the 20 day line moves up the software will pop a toast that it is a good time to buy
#
# - Not ust moving averages, the software can create similar pre-established measures for the charts.
#
# - All the parameters can be tested and can be trained with expected to observable trends for both long term and short term
#
# - This software can be then deployed
#
# - Additional provisions can be made, like on which major parameter it is showing pick or sell
#
# - Further training will make it better and finally the best trading software in market !!
#
# (Thanks for the question)
